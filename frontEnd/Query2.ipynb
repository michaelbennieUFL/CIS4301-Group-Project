# %%
#!pip install mercury
#!pip install oracledb
#!pip install matplotlib
#!pip install ipywidgets matplotlib
#!pip install ipympl

# %%
#%matplotlib notebook 
# %matplotlib widget
#make the plots interactive

# %%
import mercury as mr # for widgets
import oracledb
import random # for random data generation
from matplotlib import pyplot as plt # for chart
import time
import numpy as np
from ipywidgets import interactive, widgets, interact, interact_manual
import IPython.display
from IPython.display import display, clear_output, HTML

# %%
from pythonSqlQuery import *
from plotData import *

# %%
raw_data=execute_sql_script("../sqlScripts/Query2_DistanceFromCityCenter.sql")
# Out:
# Successfully executed script: ../sqlScripts/Query2_DistanceFromCityCenter.sql

# %% [markdown]
# ## Investigating the Spatial Dynamics of Road Safety
# In the realm of road safety analysis, understanding the intricate relationship between various factors and accident occurrences is paramount for devising effective strategies to mitigate risks and enhance overall safety measures. This section delves into a comprehensive examination of four key correlations concerning accidents and their proximity to urban centers. The analyses encompass the correlation of accident severity, total number of crashes, distance affected by a crash, and the relationship between an accident's distance from the city center and city type. Each correlation offers valuable insights into the spatial dynamics of road incidents and their implications across different urban landscapes. Through the utilization of dynamic plots, users are empowered to explore temporal variations, spatial patterns, and the interplay between urban characteristics and accident occurrences. By unraveling these correlations, this analysis aims to provide actionable insights for policymakers, urban planners, and stakeholders in the pursuit of fostering safer road environments and minimizing the societal impact of accidents.

# %%
labels=["Rural Locations", "Suburban Locations", "City Locations"]
Query2SeverityPlot(raw_data, labels,"Query 2: Correlation of Accident Severity and an Accident's Distance From City Center")

# %% [markdown]
# The plot depicts the correlation between Accident Severity and an Accident's Distance From City Center, offering a dynamic visualization tool for analyzing trends over different time periods. Users can interactively select time intervals to observe variations in accident severity based on proximity to urban, suburban, and rural areas, represented by distinct lines on the graph. This functionality facilitates a nuanced understanding of how accident severity fluctuates across different geographic zones and time frames.
#
# The plot reveals a notable trend where the lines representing Accident Severity for urban, suburban, and rural areas exhibit similar patterns, with a gradual decrease in severity over time. This observation suggests that regardless of the proximity to the city center, there is a general improvement in accident severity levels. Such a finding could imply several possibilities, including advancements in road safety measures, enhanced emergency response systems, or changes in driving behaviors and regulations. However, despite the similarity in trends among the different zones, the relatively consistent nature of the lines indicates that disparities in accident severity based on urbanization levels might not be as pronounced as initially expected.
#
# Researching the relationship between accident severity and distance from the city center is crucial for several reasons. Firstly, it provides insights into potential patterns or trends in accident severity based on urbanization levels, which can inform urban planning and transportation policies aimed at enhancing safety. Additionally, understanding this relationship can aid in resource allocation for emergency response services, as areas with higher accident severity may require greater attention and resources. Furthermore, such research can contribute to the development of targeted interventions and educational campaigns aimed at reducing accidents and mitigating their severity, ultimately fostering safer communities and transportation systems.

# %%
Query2CrashesPlot(raw_data, labels,"Query 2: Correlation of Total Number of Crashes and an Accident's Distance From City Center")

# %% [markdown]
# The plot illustrates the correlation between the Total Number of Crashes and an Accident's Distance From City Center, offering a customizable interface where users can select specific time frames and geographic zones for analysis. With distinct lines representing rural, urban, and suburban areas, users can observe how the total number of crashes varies across different locations over time. This interactive functionality allows for a comprehensive understanding of how crash frequencies fluctuate based on proximity to urban centers.
#
# The plot depicting the Correlation of Total Number of Crashes and an Accident's Distance From City Center reveals a notable trend of gradual increase in the total number of crashes across all three categories - rural, city, and suburban locations - over the specified time frame. Interestingly, the suburban location line consistently surpasses the rural line, indicating a higher frequency of crashes in suburban areas compared to rural areas. Furthermore, the line representing rural locations consistently remains above the line for city locations, suggesting a higher occurrence of crashes in rural settings compared to urban environments. This trend may be attributed to various factors, including population growth and increased vehicular traffic in suburban areas, as well as differing road conditions and driving behaviors characteristic of rural and urban settings.
#
# Researching the relationship between the Total Number of Crashes and distance from the city center is imperative for several reasons. Firstly, it enables policymakers and urban planners to identify high-risk areas and allocate resources effectively for improving road safety infrastructure and implementing targeted interventions. Additionally, understanding how crash frequencies evolve in relation to urbanization levels can inform transportation policies aimed at reducing congestion, enhancing public transit systems, and promoting sustainable urban development. Moreover, such research can aid in identifying underlying factors contributing to crash occurrences, such as traffic patterns, road conditions, and driver behavior, thereby facilitating the development of evidence-based strategies to mitigate crash risks and improve overall road safety.

# %%
Query2DistancePlot(raw_data, labels,"Query 2: Correlation of Distance Affected by a Crash and an Accident's Distance From City Center")

# %% [markdown]
# The graph depicting the Correlation of Distance Affected by a Crash and an Accident's Distance From City Center provides a comprehensive visualization tool for analyzing how the extent of crash impact varies across different geographic zones over selected time periods. Users can interactively manipulate the time intervals and select specific geographic categories - rural, city, and suburban - to observe changes in the distance affected by a crash. This functionality allows for a nuanced exploration of how crash impacts differ based on proximity to urban centers and other factors.
#
# The plot illustrating the Correlation of Distance Affected by a Crash and an Accident's Distance From City Center over the period from January 2016 to January 2019 reveals intriguing dynamics. Notably, there is a significant drop in the total distance affected by crashes for both rural and suburban locations in the initial months from January 2016 to May 2016. This decline suggests a temporary reduction in crash impacts during that period, potentially influenced by various factors such as seasonal variations, changes in traffic patterns, or specific safety initiatives implemented during that time frame. Furthermore, the line representing rural locations exhibits greater volatility compared to city and suburban lines, indicating potentially more sporadic or unpredictable patterns of crash impacts in rural areas. Despite these fluctuations, the overall trend across all three lines shows a gradual decrease in the total distance affected by crashes over the specified time period.
#
# Researching the relationship between the distance affected by a crash and an accident's distance from the city center is crucial for several reasons. Firstly, it provides insights into the spatial distribution of crash impacts, which can inform emergency response protocols and infrastructure planning aimed at minimizing the severity of accidents. Additionally, understanding this relationship can aid in identifying areas with higher vulnerability to crash impacts, facilitating targeted interventions and safety measures to mitigate their effects and enhance overall road safety. Moreover, such research can contribute to the development of predictive models and risk assessment tools to anticipate and prevent future accidents, ultimately fostering safer transportation systems and communities.

# %%
Query2CityDistancePlot(raw_data, labels, "Query2: Correlation of Accident's Distance From City Center and City Type")

# %% [markdown]
# The plot visualizes the correlation between an accident's distance from the city center and the type of city, offering users a dynamic tool to explore spatial patterns in road safety. With the ability to drag and select specific time periods, users can analyze temporal variations in this relationship, facilitating the identification of trends and patterns over time. The inclusion of three lines representing rural, city, and suburban locations enhances the graph's utility by allowing users to compare accident trends across different urban settings. By selectively viewing data for one or more city types, users can gain insights into the unique dynamics of each setting or analyze broader trends encompassing all three.
#
# The plot illustrates the correlation between an accident's distance from the city center and city type, with distinct lines representing rural, city, and suburban locations. From January 2016 to January 2019, the data reveals notable volatility across all three lines, with rural locations exhibiting relatively higher levels of fluctuation. Particularly in the initial period from January 2016 to May 2016, the accident's distance from rural locations experiences sharp rises and falls, indicating significant variability in road safety incidents during this time frame. In contrast, the accident's distance for all three lines shows a gradual upward trend over the entire period, suggesting a general increase in the distance of accidents from urban centers over time. This trend may reflect changing patterns in urban development, transportation infrastructure, or other factors influencing road safety dynamics.
#
# Researching the relationship between an accident's distance from the city center and city type is essential for several reasons. Firstly, it provides valuable insights into the spatial distribution of road safety risks, enabling the identification of areas with elevated accident rates based on city characteristics. Secondly, understanding how this relationship varies across different urban contexts can inform urban planning and infrastructure development strategies aimed at improving road safety. Additionally, such research can help policymakers develop targeted interventions tailored to specific city types, ultimately enhancing overall road safety outcomes and reducing the incidence of accidents.

# %%
button = widgets.Button(description="Back to Home Page")
output = widgets.Output()

def on_button_click(b):
    with output:
        # Redirect to the Query1 Notebook using HTML
        display(HTML('<script>window.location.href = "website.ipynb";</script>'))

button.on_click(on_button_click)

# Display the button
display(button, output)
